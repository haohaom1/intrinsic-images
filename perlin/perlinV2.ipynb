# %%
import numpy as np
import matplotlib.pyplot as plt
import vec_noise

# %%
# octaves: 5 - 15
# freq: 10-20 times of octaves

# %%
x, y = np.meshgrid(np.arange(256), np.arange(256))

# %%
x
# Out:
# array([[  0,   1,   2, ..., 253, 254, 255],
#        [  0,   1,   2, ..., 253, 254, 255],
#        [  0,   1,   2, ..., 253, 254, 255],
#        ...,
#        [  0,   1,   2, ..., 253, 254, 255],
#        [  0,   1,   2, ..., 253, 254, 255],
#        [  0,   1,   2, ..., 253, 254, 255]])

# %%
octaves = 5
freq = 25 * octaves

# %%
np.arange(5, 16) * np.arange(10, 21)
# Out:
# array([ 50,  66,  84, 104, 126, 150, 176, 204, 234, 266, 300])

# %%
img = vec_noise.snoise2(x / freq, y / freq, octaves) * 127.0 + 128.0
img.shape
# Out:
# (256, 256)

# %%
plt.imshow(img, cmap='Greys')

# %%
a, b = np.random.randint(20, size=2)

# %%
b
# Out:
# 14
